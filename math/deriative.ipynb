# %%
import numpy as np
import sympy as sp

# %%
# 1. x^2 + y^2 를 일반 미분하기

def f(x):
    return x**2

def deriative(f, x, h=1e-5):
    return (f(x+h) - f(x))/h

# %%
res=deriative(f=f, x=3)

res
# Out:
# 6.000009999951316

# %%
# 2. x^2 + y^2 + xy = z 를 편미분하기

def f2(x, y):
    return x**2 + y**2 + x*y

# %%
def partial_deriative(f, constant_var, x, y, h=1e-5):
    if constant_var == 'x':
        return (f(x+h, y) - f(x, y))/h
    elif constant_var == 'y':
        return (f(x, y+h) - f(x, y))/h
    else:
        raise ValueError('constant_var must be x or y')

# %%
res = partial_deriative(f2, 'y', 3, 4)

# %%
res
# Out:
# 11.000009999406755

# %%
import sympy as sp
import sympy.plotting as spp

x, y = sp.symbols('x, y')
z = x**2 + y**2 + x*y
spp.plot3d(z, (x, -10, 10), (y, -10, 10))
